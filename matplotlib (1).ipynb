# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Answer->
#
# Line Plot: A basic plot that displays data points connected by straight line segments.
#
# Scatter Plot: A plot that displays the relationship between two variables as points on a two-dimensional plane.
#
# Bar Chart: A chart that represents categorical data with rectangular bars with heights or lengths proportional to the values they represent.
#
# Histogram: A plot that represents the distribution of a continuous variable with bins.
#
# Pie Chart: A chart that represents the proportion of different categories in a dataset as slices of a circular pie.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
plt.scatter(x,y)
plt.show()

# %%
l1 = ["A","B","c"]
l2 = [20,30,50]
plt.bar(l1,l2)
plt.show()

# %%
x = np.random.randn(10000)

# the histogram of the data
patches = plt.hist(x, 50, density=True, facecolor='y', alpha=0.75)
plt.grid(True)
plt.show()

# %%
values= [78,21,1]
lb = ['Nitrogen','oxyzen','others']
plt.pie(values,labels=lb)

plt.show()

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Answer->
#
# A scatter plot is a chart that displays the relationship between two variables as points on a two-dimensional plane. Each point on the plot represents the values of the two variables for a single data point.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)


x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)

plt.title("Scatter Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
#
# Answer->
#
# The subplot() function is used to create multiple plots within a single figure. It allows us to arrange multiple plots in a grid-like structure, where each plot represents a specific subplot. This function is particularly useful when we want to compare multiple plots side-by-side.

# %%
import matplotlib.pyplot as plt
import numpy as np 
plt.figure(figsize=(9, 3))
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(141)
plt.plot(x1,y1)
plt.subplot(142)
plt.plot(x2,y2)

plt.subplot(143)
plt.plot(x3,y3)

plt.subplot(144)
plt.plot(x4,y4)


plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
#
#
#
# Answer->
#
# A bar plot is a plot that represents data with rectangular bars, where the length of each bar is proportional to the value being represented. Bar plots are used to compare and visualize the differences between groups of data.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company, profit)
plt.title('Profit of Companies')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

plt.barh(company, profit)
plt.title('Profit of Companies')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)
#
# Answer->
#
# A box plot is a graphical representation of a dataset that shows the median, quartiles, and outliers of the data. It is used to visualize the spread and skewness of the data, as well as to identify potential outliers.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]

# Create a box plot
plt.boxplot(data)
plt.title('Box Plot')
plt.xlabel('Box')
plt.ylabel('Value')
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.show()
